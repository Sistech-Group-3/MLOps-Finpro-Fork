# %%
import pandas as pd
import joblib

pd.set_option('display.max_columns', None) 
pd.set_option('display.width', 1000)

# %%
import os
import sys

cwd = os.getcwd()
candidates = [
    cwd,
    os.path.join(cwd, "src"),
    os.path.join(cwd, ".."),
    os.path.join(cwd, "..", "src"),
]
for candidate in candidates:
    candidate = os.path.abspath(candidate)
    if candidate not in sys.path:
        sys.path.insert(0, candidate)

from utils.get_k_shortest_paths import get_k_shortest_paths
from utils.get_safest_route_v1 import safest_route
from utils.get_routes_converter import routes_converter

# %%
G = joblib.load("../graph/chicago_walk_graph.joblib")

# %%
type(G)
# Out:
# networkx.classes.digraph.DiGraph

# %%
df = pd.read_csv('../../data/final_data.csv')
# Out:
# /var/folders/_m/x30w5wkd6l59g090_2t6sv1w0000gn/T/ipykernel_22883/53617859.py:1: DtypeWarning: Columns (0: IUCR, 1: FBI Code) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../data/final_data.csv')

# %%
df['Date'] = pd.to_datetime(df['Date'])
df_sorted_by_latitude_longitude = df.sort_values(by=['Latitude', 'Longitude'])
# Out:
# /var/folders/_m/x30w5wkd6l59g090_2t6sv1w0000gn/T/ipykernel_22883/1582584868.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
df_sorted_by_latitude_longitude.head()
# Out:
#        Unnamed: 0                Date             Block  IUCR Primary Type              Description              Location Description  Arrest  Domestic  Beat  District  Ward  Community Area FBI Code  Year              Updated On   Latitude  Longitude                       Location          Parsed_Date  Hour  Day  Month DayOfWeek  hour_sin  hour_cos   day_sin   day_cos  month_sin     month_cos  Lon_R  Lat_R  loc_arrest_ratio_historical  crime_arrest_ratio_historical  loc_domestic_ratio_historical  neighborhood_weighted_crime_index  Crime_Score  IsWeekend  temporal_modifier  CrimeDensity_Community  density_norm  neighborhood_norm  spatial_modifier  risk_score
# 93136       93136 2008-07-14 22:30:00  004XX E 138TH ST   810        THEFT                OVER $500                            STREET       0         0   533       5.0   9.0            54.0        6  2008  02/28/2018 03:56:25 PM  41.644604 -87.610728  (41.644604096, -87.610728247)  2008-07-14 22:30:00    22   14      7    Monday -0.500000  0.866025  0.299363 -0.954139  -0.500000 -8.660254e-01 -87.61  41.64                          0.0                       0.050849                            0.0                         220.130211         70.0          0           1.448690                     428      0.068066           0.047793          0.555902   56.373085
# 12545       12545 2007-04-14 23:30:00  003XX E 138TH ST  0486      BATTERY  DOMESTIC BATTERY SIMPLE                         RESIDENCE       1         1   533       5.0   9.0            54.0      08B  2007  09/07/2021 03:41:02 PM  41.644607 -87.613747  (41.644606566, -87.613746631)  2007-04-14 23:30:00    23   14      4  Saturday -0.258819  0.965926  0.299363 -0.954139   0.866025 -5.000000e-01 -87.61  41.64                          0.0                       0.249455                            0.0                         218.427269         39.0          0           1.309186                     428      0.068066           0.047423          0.555680   28.372063
# 24714       24714 2020-04-09 22:15:00  003XX E 138TH ST   460      BATTERY                   SIMPLE  FACTORY / MANUFACTURING BUILDING       0         0   533       5.0   9.0            54.0      08B  2020  04/17/2020 03:40:23 PM  41.644608 -87.613055  (41.644607723, -87.613055128)  2020-04-09 22:15:00    22    9      4  Thursday -0.500000  0.866025  0.968077 -0.250653   0.866025 -5.000000e-01 -87.61  41.64                          0.0                       0.222486                            0.0                         204.018125         39.0          0           1.404145                     428      0.068066           0.044295          0.553803   30.327195
# 89258       89258 2008-03-08 00:00:00  003XX E 138TH ST   890        THEFT            FROM BUILDING    FACTORY/MANUFACTURING BUILDING       0         0   533       5.0   9.0            54.0        6  2008  02/28/2018 03:56:25 PM  41.644608 -87.613055  (41.644607723, -87.613055128)  2008-03-08 00:00:00     0    8      3  Saturday  0.000000  1.000000  0.998717 -0.050649   1.000000  6.123234e-17 -87.61  41.64                          0.0                       0.058011                            0.0                         204.018125         70.0          0           1.463072                     428      0.068066           0.044295          0.553803   56.717808
# 93089       93089 2007-08-28 01:30:00  003XX E 138TH ST   810        THEFT                OVER $500    PARKING LOT/GARAGE(NON.RESID.)       0         0   533       5.0   9.0            54.0        6  2007  02/10/2018 03:50:01 PM  41.644608 -87.613055  (41.644607723, -87.613055128)  2007-08-28 01:30:00     1   28      8   Tuesday  0.258819  0.965926 -0.571268  0.820763  -0.866025 -5.000000e-01 -87.61  41.64                          0.0                       0.050946                            0.0                         204.018125         70.0          0           1.228570                     428      0.068066           0.044295          0.553803   47.627045

# %%
lat1, lon1 = df_sorted_by_latitude_longitude['Latitude'].iloc[1], df_sorted_by_latitude_longitude['Longitude'].iloc[0] 
lat2, lon2 = df_sorted_by_latitude_longitude['Latitude'].iloc[9], df_sorted_by_latitude_longitude['Longitude'].iloc[5] 

print('lat 1, lon 1: ', lat1, lon1)
print('lat 2, lon 2: ', lat2, lon2)
# Out:
# lat 1, lon 1:  41.644606566 -87.610728247
# lat 2, lon 2:  41.645795847 -87.615192567

# %%
routes = get_k_shortest_paths(G, lat1, lon1, lat2, lon2, weight="length", k=10)

# %%
routes_converted = routes_converter(routes, G, densify_every_m=300)
# Out:
# Route 0: 5 unique intersection points, cost=282.2m
#   -> densified to 5 points (every ~300m along the actual walk path)
# Route 1: 6 unique intersection points, cost=292.6m
#   -> densified to 6 points (every ~300m along the actual walk path)
# Route 2: 8 unique intersection points, cost=310.7m
#   -> densified to 8 points (every ~300m along the actual walk path)
# Route 3: 9 unique intersection points, cost=321.2m
#   -> densified to 9 points (every ~300m along the actual walk path)
# Route 4: 10 unique intersection points, cost=326.1m
#   -> densified to 10 points (every ~300m along the actual walk path)
# Route 5: 9 unique intersection points, cost=327.3m
#   -> densified to 9 points (every ~300m along the actual walk path)
# Route 6: 11 unique intersection points, cost=337.5m
#   -> densified to 11 points (every ~300m along the actual walk path)
# Route 7: 12 unique intersection points, cost=347.0m
#   -> densified to 12 points (every ~300m along the actual walk path)
# Route 8: 11 unique intersection points, cost=348.2m
#   -> densified to 11 points (every ~300m along the actual walk path)
# Route 9: 13 unique intersection points, cost=358.4m
#   -> densified to 13 points (every ~300m along the actual walk path)

# %%
t_query = pd.Timestamp("2026-07-27 21:00:00")  # 9pm — worth testing at a "riskier" hour

# %%
result = safest_route(
     routes=routes_converted, 
     crime_df=df_sorted_by_latitude_longitude, 
     t_query=t_query, 
     half_life_years=15, 
     bw_space=300, 
     alpha=0.7, 
     beta=0.3, 
     debug=True)
# Out:
# [debug] Temporal_Modifier = 1.363866 (same for every route -- expected)
# [debug] Spatial rescale bounds: lo=35.0142 hi=64.7170
# [debug] route=0 point=0 lat=41.64469 lon=-87.61323 base_severity=39.00 spatial_raw=60.8942 R_i=72.9404
# [debug] route=0 point=1 lat=41.64469 lon=-87.61426 base_severity=39.00 spatial_raw=61.0396 R_i=73.2008
# [debug] route=0 point=2 lat=41.64469 lon=-87.61435 base_severity=39.00 spatial_raw=61.0550 R_i=73.2283
# [debug] route=0 point=3 lat=41.64549 lon=-87.61543 base_severity=40.00 spatial_raw=61.2402 R_i=75.4462
# [debug] route=0 point=4 lat=41.64576 lon=-87.61481 base_severity=40.00 spatial_raw=61.1484 R_i=75.2775
# [debug] route=1 point=0 lat=41.64469 lon=-87.61323 base_severity=39.00 spatial_raw=60.8942 R_i=72.9404
# [debug] route=1 point=1 lat=41.64469 lon=-87.61426 base_severity=39.00 spatial_raw=61.0396 R_i=73.2008
# [debug] route=1 point=2 lat=41.64462 lon=-87.61425 base_severity=39.00 spatial_raw=60.9993 R_i=73.1286
# [debug] route=1 point=3 lat=41.64469 lon=-87.61435 base_severity=39.00 spatial_raw=61.0550 R_i=73.2283
# [debug] route=1 point=4 lat=41.64549 lon=-87.61543 base_severity=40.00 spatial_raw=61.2402 R_i=75.4462
# [debug] route=1 point=5 lat=41.64576 lon=-87.61481 base_severity=40.00 spatial_raw=61.1484 R_i=75.2775
# [debug] route=2 point=0 lat=41.64469 lon=-87.61323 base_severity=39.00 spatial_raw=60.8942 R_i=72.9404
# [debug] route=2 point=1 lat=41.64469 lon=-87.61426 base_severity=39.00 spatial_raw=61.0396 R_i=73.2008
# [debug] route=2 point=2 lat=41.64469 lon=-87.61435 base_severity=39.00 spatial_raw=61.0550 R_i=73.2283
# [debug] route=2 point=3 lat=41.64469 lon=-87.61453 base_severity=39.00 spatial_raw=61.0852 R_i=73.2824
# [debug] route=2 point=4 lat=41.64547 lon=-87.61557 base_severity=40.00 spatial_raw=61.2491 R_i=75.4624
# [debug] route=2 point=5 lat=41.64553 lon=-87.61549 base_severity=40.00 spatial_raw=61.2364 R_i=75.4392
# [debug] route=2 point=6 lat=41.64549 lon=-87.61543 base_severity=40.00 spatial_raw=61.2402 R_i=75.4462
# [debug] route=2 point=7 lat=41.64576 lon=-87.61481 base_severity=40.00 spatial_raw=61.1484 R_i=75.2775
# [debug] route=3 point=0 lat=41.64469 lon=-87.61323 base_severity=39.00 spatial_raw=60.8942 R_i=72.9404
# [debug] route=3 point=1 lat=41.64469 lon=-87.61426 base_severity=39.00 spatial_raw=61.0396 R_i=73.2008
# [debug] route=3 point=2 lat=41.64462 lon=-87.61425 base_severity=39.00 spatial_raw=60.9993 R_i=73.1286
# [debug] route=3 point=3 lat=41.64469 lon=-87.61435 base_severity=39.00 spatial_raw=61.0550 R_i=73.2283
# [debug] route=3 point=4 lat=41.64469 lon=-87.61453 base_severity=39.00 spatial_raw=61.0852 R_i=73.2824
# [debug] route=3 point=5 lat=41.64547 lon=-87.61557 base_severity=40.00 spatial_raw=61.2491 R_i=75.4624
# [debug] route=3 point=6 lat=41.64553 lon=-87.61549 base_severity=40.00 spatial_raw=61.2364 R_i=75.4392
# [debug] route=3 point=7 lat=41.64549 lon=-87.61543 base_severity=40.00 spatial_raw=61.2402 R_i=75.4462
# [debug] route=3 point=8 lat=41.64576 lon=-87.61481 base_severity=40.00 spatial_raw=61.1484 R_i=75.2775
# [debug] route=4 point=0 lat=41.64469 lon=-87.61323 base_severity=39.00 spatial_raw=60.8942 R_i=72.9404
# [debug] route=4 point=1 lat=41.64469 lon=-87.61426 base_severity=39.00 spatial_raw=61.0396 R_i=73.2008
# [debug] route=4 point=2 lat=41.64462 lon=-87.61425 base_severity=39.00 spatial_raw=60.9993 R_i=73.1286
# [debug] route=4 point=3 lat=41.64459 lon=-87.61425 base_severity=39.00 spatial_raw=60.9813 R_i=73.0963
# [debug] route=4 point=4 lat=41.64459 lon=-87.61441 base_severity=39.00 spatial_raw=61.0085 R_i=73.1451
# [debug] route=4 point=5 lat=41.64469 lon=-87.61453 base_severity=39.00 spatial_raw=61.0852 R_i=73.2824
# [debug] route=4 point=6 lat=41.64547 lon=-87.61557 base_severity=40.00 spatial_raw=61.2491 R_i=75.4624
# [debug] route=4 point=7 lat=41.64553 lon=-87.61549 base_severity=40.00 spatial_raw=61.2364 R_i=75.4392
# [debug] route=4 point=8 lat=41.64549 lon=-87.61543 base_severity=40.00 spatial_raw=61.2402 R_i=75.4462
# [debug] route=4 point=9 lat=41.64576 lon=-87.61481 base_severity=40.00 spatial_raw=61.1484 R_i=75.2775
# [debug] route=5 point=0 lat=41.64469 lon=-87.61323 base_severity=39.00 spatial_raw=60.8942 R_i=72.9404
# [debug] route=5 point=1 lat=41.64469 lon=-87.61426 base_severity=39.00 spatial_raw=61.0396 R_i=73.2008
# [debug] route=5 point=2 lat=41.64462 lon=-87.61425 base_severity=39.00 spatial_raw=60.9993 R_i=73.1286
# [debug] route=5 point=3 lat=41.64459 lon=-87.61425 base_severity=39.00 spatial_raw=60.9813 R_i=73.0963
# [debug] route=5 point=4 lat=41.64459 lon=-87.61441 base_severity=39.00 spatial_raw=61.0085 R_i=73.1451
# [debug] route=5 point=5 lat=41.64469 lon=-87.61453 base_severity=39.00 spatial_raw=61.0852 R_i=73.2824
# [debug] route=5 point=6 lat=41.64469 lon=-87.61435 base_severity=39.00 spatial_raw=61.0550 R_i=73.2283
# [debug] route=5 point=7 lat=41.64549 lon=-87.61543 base_severity=40.00 spatial_raw=61.2402 R_i=75.4462
# [debug] route=5 point=8 lat=41.64576 lon=-87.61481 base_severity=40.00 spatial_raw=61.1484 R_i=75.2775
# [debug] route=6 point=0 lat=41.64469 lon=-87.61323 base_severity=39.00 spatial_raw=60.8942 R_i=72.9404
# [debug] route=6 point=1 lat=41.64469 lon=-87.61426 base_severity=39.00 spatial_raw=61.0396 R_i=73.2008
# [debug] route=6 point=2 lat=41.64469 lon=-87.61435 base_severity=39.00 spatial_raw=61.0550 R_i=73.2283
# [debug] route=6 point=3 lat=41.64462 lon=-87.61425 base_severity=39.00 spatial_raw=60.9993 R_i=73.1286
# [debug] route=6 point=4 lat=41.64459 lon=-87.61425 base_severity=39.00 spatial_raw=60.9813 R_i=73.0963
# [debug] route=6 point=5 lat=41.64459 lon=-87.61441 base_severity=39.00 spatial_raw=61.0085 R_i=73.1451
# [debug] route=6 point=6 lat=41.64469 lon=-87.61453 base_severity=39.00 spatial_raw=61.0852 R_i=73.2824
# [debug] route=6 point=7 lat=41.64547 lon=-87.61557 base_severity=40.00 spatial_raw=61.2491 R_i=75.4624
# [debug] route=6 point=8 lat=41.64553 lon=-87.61549 base_severity=40.00 spatial_raw=61.2364 R_i=75.4392
# [debug] route=6 point=9 lat=41.64549 lon=-87.61543 base_severity=40.00 spatial_raw=61.2402 R_i=75.4462
# [debug] route=6 point=10 lat=41.64576 lon=-87.61481 base_severity=40.00 spatial_raw=61.1484 R_i=75.2775
# [debug] route=7 point=0 lat=41.64469 lon=-87.61323 base_severity=39.00 spatial_raw=60.8942 R_i=72.9404
# [debug] route=7 point=1 lat=41.64469 lon=-87.61426 base_severity=39.00 spatial_raw=61.0396 R_i=73.2008
# [debug] route=7 point=2 lat=41.64462 lon=-87.61425 base_severity=39.00 spatial_raw=60.9993 R_i=73.1286
# [debug] route=7 point=3 lat=41.64459 lon=-87.61425 base_severity=39.00 spatial_raw=60.9813 R_i=73.0963
# [debug] route=7 point=4 lat=41.64459 lon=-87.61441 base_severity=39.00 spatial_raw=61.0085 R_i=73.1451
# [debug] route=7 point=5 lat=41.64459 lon=-87.61453 base_severity=39.00 spatial_raw=61.0317 R_i=73.1865
# [debug] route=7 point=6 lat=41.64469 lon=-87.61465 base_severity=40.00 spatial_raw=61.1063 R_i=75.2003
# [debug] route=7 point=7 lat=41.64469 lon=-87.61453 base_severity=39.00 spatial_raw=61.0852 R_i=73.2824
# [debug] route=7 point=8 lat=41.64547 lon=-87.61557 base_severity=40.00 spatial_raw=61.2491 R_i=75.4624
# [debug] route=7 point=9 lat=41.64553 lon=-87.61549 base_severity=40.00 spatial_raw=61.2364 R_i=75.4392
# [debug] route=7 point=10 lat=41.64549 lon=-87.61543 base_severity=40.00 spatial_raw=61.2402 R_i=75.4462
# [debug] route=7 point=11 lat=41.64576 lon=-87.61481 base_severity=40.00 spatial_raw=61.1484 R_i=75.2775
# [debug] route=8 point=0 lat=41.64469 lon=-87.61323 base_severity=39.00 spatial_raw=60.8942 R_i=72.9404
# [debug] route=8 point=1 lat=41.64469 lon=-87.61426 base_severity=39.00 spatial_raw=61.0396 R_i=73.2008
# [debug] route=8 point=2 lat=41.64462 lon=-87.61425 base_severity=39.00 spatial_raw=60.9993 R_i=73.1286
# [debug] route=8 point=3 lat=41.64459 lon=-87.61425 base_severity=39.00 spatial_raw=60.9813 R_i=73.0963
# [debug] route=8 point=4 lat=41.64459 lon=-87.61441 base_severity=39.00 spatial_raw=61.0085 R_i=73.1451
# [debug] route=8 point=5 lat=41.64459 lon=-87.61453 base_severity=39.00 spatial_raw=61.0317 R_i=73.1865
# [debug] route=8 point=6 lat=41.64469 lon=-87.61465 base_severity=40.00 spatial_raw=61.1063 R_i=75.2003
# [debug] route=8 point=7 lat=41.64469 lon=-87.61453 base_severity=39.00 spatial_raw=61.0852 R_i=73.2824
# [debug] route=8 point=8 lat=41.64469 lon=-87.61435 base_severity=39.00 spatial_raw=61.0550 R_i=73.2283
# [debug] route=8 point=9 lat=41.64549 lon=-87.61543 base_severity=40.00 spatial_raw=61.2402 R_i=75.4462
# [debug] route=8 point=10 lat=41.64576 lon=-87.61481 base_severity=40.00 spatial_raw=61.1484 R_i=75.2775
# [debug] route=9 point=0 lat=41.64469 lon=-87.61323 base_severity=39.00 spatial_raw=60.8942 R_i=72.9404
# [debug] route=9 point=1 lat=41.64469 lon=-87.61426 base_severity=39.00 spatial_raw=61.0396 R_i=73.2008
# [debug] route=9 point=2 lat=41.64469 lon=-87.61435 base_severity=39.00 spatial_raw=61.0550 R_i=73.2283
# [debug] route=9 point=3 lat=41.64462 lon=-87.61425 base_severity=39.00 spatial_raw=60.9993 R_i=73.1286
# [debug] route=9 point=4 lat=41.64459 lon=-87.61425 base_severity=39.00 spatial_raw=60.9813 R_i=73.0963
# [debug] route=9 point=5 lat=41.64459 lon=-87.61441 base_severity=39.00 spatial_raw=61.0085 R_i=73.1451
# [debug] route=9 point=6 lat=41.64459 lon=-87.61453 base_severity=39.00 spatial_raw=61.0317 R_i=73.1865
# [debug] route=9 point=7 lat=41.64469 lon=-87.61465 base_severity=40.00 spatial_raw=61.1063 R_i=75.2003
# [debug] route=9 point=8 lat=41.64469 lon=-87.61453 base_severity=39.00 spatial_raw=61.0852 R_i=73.2824
# [debug] route=9 point=9 lat=41.64547 lon=-87.61557 base_severity=40.00 spatial_raw=61.2491 R_i=75.4624
# [debug] route=9 point=10 lat=41.64553 lon=-87.61549 base_severity=40.00 spatial_raw=61.2364 R_i=75.4392
# [debug] route=9 point=11 lat=41.64549 lon=-87.61543 base_severity=40.00 spatial_raw=61.2402 R_i=75.4462
# [debug] route=9 point=12 lat=41.64576 lon=-87.61481 base_severity=40.00 spatial_raw=61.1484 R_i=75.2775

# %%
print("\n=== FINAL RESULT ===")
print("Safest route index:", result["safest_route_index"])
print(f"  Mean risk: {result['R_route_mean']:.4f}")
print(f"  Max risk:  {result['R_route_max']:.4f}")
print(f"  Combined:  {result['combined_score']:.4f}")
print("\nAll paths:")
for s in result["all_scores"]:
    print(f"  Route {s['route_index']}:  mean={s['R_route_mean']:.4f}  "
          f"max={s['R_route_max']:.4f}  combined={s['combined_score']:.4f}"
        #   //f"  point_risks={[f'{x:.4f}' for x in s['point_risks']]}"
          )
# Out:
# === FINAL RESULT ===
# Safest route index: 5
#   Mean risk: 74.4681
#   Max risk:  75.4462
#   Combined:  74.7615
#
# All paths:
#   Route 0:  mean=74.6715  max=75.4462  combined=74.9039
#   Route 1:  mean=74.6174  max=75.4462  combined=74.8660
#   Route 2:  mean=74.6454  max=75.4624  combined=74.8905
#   Route 3:  mean=74.5969  max=75.4624  combined=74.8565
#   Route 4:  mean=74.5716  max=75.4624  combined=74.8389
#   Route 5:  mean=74.4681  max=75.4462  combined=74.7615
#   Route 6:  mean=74.5253  max=75.4624  combined=74.8065
#   Route 7:  mean=74.5702  max=75.4624  combined=74.8379
#   Route 8:  mean=74.4729  max=75.4462  combined=74.7649
#   Route 9:  mean=74.5267  max=75.4624  combined=74.8074

# %%
from utils.visualize_route import visualize_safest_result

visualize_safest_result(result, routes_converted, save_path="safest_route_v1.html")
# Out:
# Saved to safest_route.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1cf95470667bf91bc7f05f49b03208d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1cf95470667bf91bc7f05f49b03208d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1cf95470667bf91bc7f05f49b03208d5 = L.map(
#                 &quot;map_1cf95470667bf91bc7f05f49b03208d5&quot;,
#                 {
#                     center: [41.644687, -87.6143496],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_11fa9bcdefb4cca1c02395838fb3c08b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_11fa9bcdefb4cca1c02395838fb3c08b.addTo(map_1cf95470667bf91bc7f05f49b03208d5);
#
#
#             var poly_line_3101c7ec8c375f230ccf9fd546580cfe = L.polyline(
#                 [[41.6446914, -87.6132343], [41.6446873, -87.6142565], [41.644687, -87.6143496], [41.6454852, -87.615427], [41.6457568, -87.6148143]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1cf95470667bf91bc7f05f49b03208d5);
#
#
#             poly_line_3101c7ec8c375f230ccf9fd546580cfe.bindTooltip(
#                 `&lt;div&gt;
#                      route_0
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_1ada5e48d62da81114374672ea9a1dfa = L.polyline(
#                 [[41.6446914, -87.6132343], [41.6446873, -87.6142565], [41.6446218, -87.6142515], [41.644687, -87.6143496], [41.6454852, -87.615427], [41.6457568, -87.6148143]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1cf95470667bf91bc7f05f49b03208d5);
#
#
#             poly_line_1ada5e48d62da81114374672ea9a1dfa.bindTooltip(
#                 `&lt;div&gt;
#                      route_1
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_453598e3f209b56548057b670d17747a = L.polyline(
#                 [[41.6446914, -87.6132343], [41.6446873, -87.6142565], [41.644687, -87.6143496], [41.6446866, -87.6145286], [41.6454748, -87.6155668], [41.6455344, -87.6154916], [41.6454852, -87.615427], [41.6457568, -87.6148143]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;gray&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.5, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1cf95470667bf91bc7f05f49b03208d5);
#
#
#             poly_line_453598e3f209b56548057b670d17747a.bindTooltip(
#                 `&lt;div&gt;
#                      route_2
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_45ea95e6fd4b094146203b3f8623f75b = L.polyline(
#                 [[41.6446914, -87.6132343], [41.6446873, -87.6142565], [41.6446218, -87.6142515], [41.644687, -87.6143496], [41.6446866, -87.6145286], [41.6454748, -87.6155668], [41.6455344, -87.6154916], [41.6454852, -87.615427], [41.6457568, -87.6148143]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;gray&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;gray&qu
